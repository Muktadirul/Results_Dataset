# %%
import pandas as pd
from glob import glob

# %%
def data_merge(paths):
    data = []
    for path in paths:
        data.append(pd.read_csv(path,index_col=None, header=0))
    return data

# %%
path = '/home/raian/Desktop/automate-score-el-qs-fn-std-stderr/Final_Result/37-texon/*.*g.*/'
Estmeted_EL = glob(path+'Result_of__Estimated__EL__*.csv')
Estmeted_FN = glob(path+'Result_of__Estimated__FN__*.csv')
Estmeted_QS = glob(path+'Result_of__Estimated__QS__*.csv')

EL_frame = pd.concat(data_merge(Estmeted_EL))
FN_frame = pd.concat(data_merge(Estmeted_FN))
QS_frame = pd.concat(data_merge(Estmeted_QS))

EL_frame['Score'] = EL_frame.apply(lambda row: str(row['Score']), axis=1)
EL_frame['stderr'] = EL_frame.apply(lambda row: str(row['stderr']), axis=1)

FN_frame['Score'] = FN_frame.apply(lambda row: str(row['Score']), axis=1)
FN_frame['stderr'] = FN_frame.apply(lambda row: str(row['stderr']), axis=1)

QS_frame['Score'] = QS_frame.apply(lambda row: str(row['Score']), axis=1)
QS_frame['stderr'] = QS_frame.apply(lambda row: str(row['stderr']), axis=1)

path1 = '/home/raian/Desktop/automate-score-el-qs-fn-std-stderr/Final_Result/37-texon/37_'
writer = pd.ExcelWriter(path1+'EL_QS_FN_01_12_2018.xlsx', engine='xlsxwriter')

# # Write each dataframe to a different worksheet.
EL_frame.to_excel(writer, sheet_name='EL')
QS_frame.to_excel(writer, sheet_name='QS')
FN_frame.to_excel(writer, sheet_name='FN')

# # Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
EL_frame
# Out:
#              name     Score         stderr                Type
# 0   EL_Phylonet50     972.3  11.3727964899    noscale.50g.500b
# 1       EL_True50    1052.3  14.6501023887    noscale.50g.500b
# 2     EL_Astral50    1042.3  15.1829015672    noscale.50g.500b
# 0  EL_Phylonet200    5617.1   25.973630859   scale2d.200g.500b
# 1      EL_True200   6003.55  36.1965796036   scale2d.200g.500b
# 2    EL_Astral200    6050.0  40.5797363225   scale2d.200g.500b
# 0  EL_Phylonet200    3156.1   19.011430772   scale2u.200g.500b
# 1      EL_True200   3464.85  24.4016674635   scale2u.200g.500b
# 2    EL_Astral200    3415.9  27.5165313948   scale2u.200g.500b
# 0  EL_Phylonet200    3024.0  15.2517212143  noscale.200g.1000b
# 1      EL_True200   3139.45  18.3129018727  noscale.200g.1000b
# 2    EL_Astral200   3143.95  19.3622667836  noscale.200g.1000b
# 0  EL_Phylonet200    5918.5  28.2686663994   noscale.200g.250b
# 1      EL_True200   6708.55  43.3053966037   noscale.200g.250b
# 2    EL_Astral200    6485.1  75.1589615415   noscale.200g.250b
# 0  EL_Phylonet200    5617.1   25.973630859   noscale.200g.500b
# 1      EL_True200   6003.55  36.1965796036   noscale.200g.500b
# 2    EL_Astral200    6050.0  40.5797363225   noscale.200g.500b
# 0  EL_Phylonet800  15871.05  45.3949597973   noscale.800g.500b
# 1      EL_True800  17084.45  52.1565659817   noscale.800g.500b
# 2    EL_Astral800   17099.6  52.9995943381   noscale.800g.500b
# 0  EL_Phylonet400    5575.9  24.2550819417  noscale.400g.1500b
# 1      EL_True400    5730.8   26.340007593  noscale.400g.1500b
# 2    EL_Astral400    5707.2  28.3562338825  noscale.400g.1500b
# 0  EL_Phylonet400   7929.85  32.0612909129   noscale.400g.500b
# 1      EL_True400   8544.65  38.0043599472   noscale.400g.500b
# 2    EL_Astral400    8551.3   36.304896364   noscale.400g.500b
# 0  EL_Phylonet200    2783.3  13.2915574708  noscale.200g.1500b
# 1      EL_True200    2865.4   15.229970453  noscale.200g.1500b
# 2    EL_Astral200   2865.05  16.6786502751  noscale.200g.1500b
# 0  EL_Phylonet100    1970.3   16.394983989   noscale.100g.500b
# 1      EL_True100    2129.0  21.4168158231   noscale.100g.500b
# 2    EL_Astral100    2104.1  23.1615953682   noscale.100g.500b
# 0   EL_Phylonet25    488.15  10.3426966986    noscale.25g.500b
# 1       EL_True25     534.3  12.4621627337    noscale.25g.500b
# 2     EL_Astral25     517.9   12.558244304    noscale.25g.500b

# %%
QS_frame
# Out:
#              name        Score         stderr                Type
# 0     QS_Astral50   2821123.85  5806.07229126    noscale.50g.500b
# 1       QS_True50   2816708.35  5971.32064424    noscale.50g.500b
# 2   QS_Phylonet50    2816191.4  6119.79018243    noscale.50g.500b
# 0    QS_Astral200  10007425.55   19043.531042   scale2d.200g.500b
# 1      QS_True200  10003929.55  19160.5876401   scale2d.200g.500b
# 2  QS_Phylonet200    9970770.0  19309.0623295   scale2d.200g.500b
# 0    QS_Astral200   11944654.4  9079.93399684   scale2u.200g.500b
# 1      QS_True200  11943759.05  9108.72310493   scale2u.200g.500b
# 2  QS_Phylonet200  11919007.15  8492.01117441   scale2u.200g.500b
# 0    QS_Astral200  11586641.45  11554.8708566  noscale.200g.1000b
# 1      QS_True200  11584969.95  11625.3076511  noscale.200g.1000b
# 2  QS_Phylonet200  11568183.15  11335.6034639  noscale.200g.1000b
# 0    QS_Astral200  10561825.45  16244.9518989   noscale.200g.250b
# 1      QS_True200   10557321.6  16185.2134866   noscale.200g.250b
# 2  QS_Phylonet200   10491273.0  19153.7362272   noscale.200g.250b
# 0    QS_Astral200  10007425.55   19043.531042   noscale.200g.500b
# 1      QS_True200  10003929.55  19160.5876401   noscale.200g.500b
# 2  QS_Phylonet200    9970770.0  19309.0623295   noscale.200g.500b
# 0    QS_Astral800  45096874.45  25257.6373263   noscale.800g.500b
# 1      QS_True800   45096639.8   25249.620975   noscale.800g.500b
# 2  QS_Phylonet800   44996519.2  27012.7969224   noscale.800g.500b
# 0    QS_Astral400   23314610.0  25072.7377624  noscale.400g.1500b
# 1      QS_True400   23314499.8  25106.4656632  noscale.400g.1500b
# 2  QS_Phylonet400   23285228.3  28832.5131801  noscale.400g.1500b
# 0    QS_Astral400  22534424.55  17335.6557607   noscale.400g.500b
# 1      QS_True400   22531906.2  17443.4846274   noscale.400g.500b
# 2  QS_Phylonet400   22487163.0  18209.8493191   noscale.400g.500b
# 0    QS_Astral200  11658445.25  11249.9600766  noscale.200g.1500b
# 1      QS_True200   11657249.9  11378.1901465  noscale.200g.1500b
# 2  QS_Phylonet200  11645163.15   11834.234429  noscale.200g.1500b
# 0    QS_Astral100   5636032.85  8878.54388548   noscale.100g.500b
# 1      QS_True100   5630260.55  8964.55334093   noscale.100g.500b
# 2  QS_Phylonet100    5622636.4  8698.18012558   noscale.100g.500b
# 0     QS_Astral25   1414559.25  4564.01296606    noscale.25g.500b
# 1       QS_True25    1410250.7  4547.98975598    noscale.25g.500b
# 2   QS_Phylonet25   1410127.95  4839.72067607    noscale.25g.500b

# %%
FN_frame
# Out:
#         name         Score        stderr                Type
# 0   FN_ast50         0.075  0.0091779316    noscale.50g.500b
# 1   FN_phy50  0.1264705882  0.0072343376    noscale.50g.500b
# 0  FN_ast200  0.0510835913  0.0052913583   scale2d.200g.500b
# 1  FN_phy200  0.2058823529  0.0058823529   scale2d.200g.500b
# 0  FN_ast200         0.025  0.0047765829   scale2u.200g.500b
# 1  FN_phy200  0.1161764706  0.0038768901   scale2u.200g.500b
# 0  FN_ast200  0.0220588235  0.0045919103  noscale.200g.1000b
# 1  FN_phy200  0.1029411765  0.0044117647  noscale.200g.1000b
# 0  FN_ast200  0.0632352941  0.0081282433   noscale.200g.250b
# 1  FN_phy200  0.2147058824  0.0046966822   noscale.200g.250b
# 0  FN_ast200  0.0510835913  0.0052913583   noscale.200g.500b
# 1  FN_phy200  0.2058823529  0.0058823529   noscale.200g.500b
# 0  FN_ast800  0.0073529412  0.0028477819   noscale.800g.500b
# 1  FN_phy800  0.1235294118  0.0033534571   noscale.800g.500b
# 0  FN_ast400  0.0058823529  0.0037203267  noscale.400g.1500b
# 1  FN_phy400  0.0764705882  0.0085243393  noscale.400g.1500b
# 0  FN_ast400  0.0147058824  0.0038908108   noscale.400g.500b
# 1  FN_phy400         0.125  0.0045919103   noscale.400g.500b
# 0  FN_ast200  0.0176470588  0.0038348249  noscale.200g.1500b
# 1  FN_phy200  0.0852941176  0.0050516365  noscale.200g.1500b
# 0  FN_ast100  0.0705882353  0.0076130465   noscale.100g.500b
# 1  FN_phy100         0.125  0.0050409225   noscale.100g.500b
# 0   FN_ast25  0.1132352941  0.0075774547    noscale.25g.500b
# 1   FN_phy25  0.1455882353  0.0067310544    noscale.25g.500b
